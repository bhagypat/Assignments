# %%
university_system = {
    "universities": {
        "GTU_India": {
            "location": "Chennai",
            "ranking": 5,
            "faculties": {
                "engineering": {
                    "dean": "Dr. Narayan",
                    "departments": {
                        "computer_science": {
                            "hod": "Dr. Anish",
                            "labs": {
                                "AI Lab": {
                                    "incharge": "Dr. Meera",
                                    "research_projects": {
                                        "DeepVision": {
                                            "funding": 250000,
                                            "researchers": ["Arjun", "Sneha"],
                                            "status": "ongoing"
                                        },
                                        "RoboMind": {
                                            "funding": 180000,
                                            "researchers": ["Ishita", "Rahul"],
                                            "status": "completed"
                                        }
                                    }
                                },
                                "Systems Lab": {
                                    "incharge": "Dr. Raman",
                                    "research_projects": {
                                        "CloudScale": {
                                            "funding": 300000,
                                            "researchers": ["Karan", "Neha"],
                                            "status": "ongoing"
                                        }
                                    }
                                }
                            },
                            "courses": {
                                "Data Structures": {
                                    "credits": 4,
                                    "students_enrolled": 120
                                },
                                "Machine Learning": {
                                    "credits": 3,
                                    "students_enrolled": 90
                                }
                            }
                        }
                    }
                },
                "management": {
                    "dean": "Dr. Kapoor",
                    "departments": {
                        "finance": {
                            "hod": "Dr. Iyer",
                            "courses": {
                                "Corporate Finance": {
                                    "credits": 3,
                                    "students_enrolled": 80
                                }
                            }
                        }
                    }
                }
            }
        },
        "GTU_Singapore": {
            "location": "Singapore",
            "ranking": 2,
            "faculties": {
                "engineering": {
                    "dean": "Dr. Lee",
                    "departments": {
                        "robotics": {
                            "hod": "Dr. Tan",
                            "labs": {
                                "Automation Lab": {
                                    "incharge": "Dr. Wong",
                                    "research_projects": {
                                        "AutoNav": {
                                            "funding": 400000,
                                            "researchers": ["Jason", "Lily"],
                                            "status": "ongoing"
                                        }
                                    }
                                }
                            }
                        }
                    }
                }
            }
        }
    }
}

# %%
# Questions to improve your understanding of dictionary


# 1.	Print the location of GTU_India.
print(university_system["universities"]["GTU_India"]["location"])
# 2.	Print the dean of the engineering faculty in GTU_Singapore.
print(university_system["universities"]["GTU_Singapore"]["faculties"]["engineering"]["dean"])
# 3.	Print the HOD of the computer_science department.
print(university_system["universities"]["GTU_India"]["faculties"]["engineering"]["departments"]["computer_science"]["hod"])
# 4.	Print all labs under computer_science.
cs = university_system["universities"]["GTU_India"]["faculties"]["engineering"]["departments"]["computer_science"]
print(list(cs["labs"].keys()))
# 5.	Print the funding amount of the "DeepVision" project.
print(cs["labs"]["AI Lab"]["research_projects"]["DeepVision"]["funding"])
# 6.	Print all research project names in GTU_India.
india_labs = cs["labs"]
for lab_name, lab_data in india_labs.items():
    for project in lab_data["research_projects"]:
        print(project)
# 7.	Print all ongoing projects in GTU_India.
for lab_name, lab_data in india_labs.items():
    for proj_name, proj_data in lab_data["research_projects"].items():
        if proj_data["status"] == "ongoing":
            print(proj_name)
# 8.	Calculate the total funding for all projects in AI Lab.
ai_lab_projects = cs["labs"]["AI Lab"]["research_projects"]
total_funding = sum(p["funding"] for p in ai_lab_projects.values())
print(total_funding)
# 9.	Print all researchers working under Systems Lab.
sys_lab_projects = cs["labs"]["Systems Lab"]["research_projects"]
for proj in sys_lab_projects.values():
    print(proj["researchers"])
# 10.	Count total students enrolled in all computer_science courses.
total_students = sum(c["students_enrolled"] for c in cs["courses"].values())
print(total_students)
# 11.	Print all university names in the system.
print(list(university_system["universities"].keys()))
# 12.	Print all faculty names under GTU_India.
print(list(university_system["universities"]["GTU_India"]["faculties"].keys()))
# 13.	Print all department names across all universities.
for uni_name, uni_data in university_system["universities"].items():
    for fac_name, fac_data in uni_data["faculties"].items():
        print(list(fac_data["departments"].keys()))
# 14.	Print all deans in the entire system.
for uni_data in university_system["universities"].values():
    for fac_data in uni_data["faculties"].values():
        print(fac_data["dean"])
# 15.	Print all project names across both universities.
for uni_data in university_system["universities"].values():
    for fac_data in uni_data["faculties"].values():
        for dept_data in fac_data["departments"].values():
            if "labs" in dept_data:
                for lab_data in dept_data["labs"].values():
                    print(list(lab_data["research_projects"].keys()))
# 16.	Add a new research project under AI Lab.
cs["labs"]["AI Lab"]["research_projects"]["NeuralEdge"] = {
    "funding": 150000,
    "researchers": ["Priya", "Dev"],
    "status": "ongoing"
}
print(cs["labs"]["AI Lab"]["research_projects"]["NeuralEdge"])
# 17.	Change the status of "DeepVision" to completed.
cs["labs"]["AI Lab"]["research_projects"]["DeepVision"]["status"] = "completed"
print(cs["labs"]["AI Lab"]["research_projects"]["DeepVision"]["status"])
# 18.	Increase funding of "CloudScale" by 50,000.
sys_lab_projects["CloudScale"]["funding"] += 50000
print(sys_lab_projects["CloudScale"]["funding"])
# 19.	Add a new university to the system.
university_system["universities"]["GTU_Dubai"] = {
    "location": "Dubai",
    "ranking": 3,
    "faculties": {}
}
print(university_system["universities"]["GTU_Dubai"])
# 20.	Add a new course under finance department.
finance = university_system["universities"]["GTU_India"]["faculties"]["management"]["departments"]["finance"]
finance["courses"]["Investment Banking"] = {"credits": 3, "students_enrolled": 60}
print(finance["courses"])
# 21.	Find the project with the highest funding.
all_projects = {}
for uni_data in university_system["universities"].values():
    for fac_data in uni_data["faculties"].values():
        for dept_data in fac_data["departments"].values():
            if "labs" in dept_data:
                for lab_data in dept_data["labs"].values():
                    all_projects.update(lab_data["research_projects"])

top_project = max(all_projects, key=lambda p: all_projects[p]["funding"])
print(top_project, all_projects[top_project]["funding"])
# 22.	Find total funding across all universities.
total = sum(p["funding"] for p in all_projects.values())
print(total)
# 23.	Find the university with the best ranking.
best_uni = min(university_system["universities"], key=lambda u: university_system["universities"][u]["ranking"])
print(best_uni)
# 24.	Print all completed projects.
for name, data in all_projects.items():
    if data["status"] == "completed":
        print(name)
# 25.	Count total number of researchers in GTU_India.
count = 0
for lab_data in cs["labs"].values():
    for proj in lab_data["research_projects"].values():
        count += len(proj["researchers"])
print(count)
# 26.	Find which lab has the maximum funding.
lab_funding = {}
for uni_data in university_system["universities"].values():
    for fac_data in uni_data["faculties"].values():
        for dept_data in fac_data["departments"].values():
            if "labs" in dept_data:
                for lab_name, lab_data in dept_data["labs"].items():
                    lab_funding[lab_name] = sum(p["funding"] for p in lab_data["research_projects"].values())

top_lab = max(lab_funding, key=lambda l: lab_funding[l])
print(top_lab, lab_funding[top_lab])
# 27.	Print projects grouped by status (ongoing/completed).
grouped = {"ongoing": [], "completed": []}
for name, data in all_projects.items():
    grouped[data["status"]].append(name)
print(grouped)
# 28.	Print all courses with more than 100 students enrolled.
for uni_data in university_system["universities"].values():
    for fac_data in uni_data["faculties"].values():
        for dept_data in fac_data["departments"].values():
            if "courses" in dept_data:
                for course_name, course_data in dept_data["courses"].items():
                    if course_data["students_enrolled"] > 100:
                        print(course_name)
# 29.	Find total number of faculties in the entire system.
def find_project(project_name):
    for uni_name, uni_data in university_system["universities"].items():
        for fac_data in uni_data["faculties"].values():
            for dept_data in fac_data["departments"].values():
                if "labs" in dept_data:
                    for lab_data in dept_data["labs"].values():
                        if project_name in lab_data["research_projects"]:
                            print(f"University: {uni_name}")
                            print(f"Project: {project_name}")
                            print(lab_data["research_projects"][project_name])
                            return
    print("Project not found")

find_project("AutoNav")
# 30.	Write a function that searches for a project name and prints its full details.
def find_project(project_name):
    for uni_name, uni_data in university_system["universities"].items():
        for fac_data in uni_data["faculties"].values():
            for dept_data in fac_data["departments"].values():
                if "labs" in dept_data:
                    for lab_data in dept_data["labs"].values():
                        if project_name in lab_data["research_projects"]:
                            print(f"University: {uni_name}")
                            print(f"Project: {project_name}")
                            print(lab_data["research_projects"][project_name])
                            return
    print("Project not found")

find_project("AutoNav")
# Out:
# Chennai
# Dr. Lee
# Dr. Anish
# ['AI Lab', 'Systems Lab']
# 250000
# DeepVision
# RoboMind
# CloudScale
# DeepVision
# CloudScale
# 430000
# ['Karan', 'Neha']
# 210
# ['GTU_India', 'GTU_Singapore']
# ['engineering', 'management']
# ['computer_science']
# ['finance']
# ['robotics']
# Dr. Narayan
# Dr. Kapoor
# Dr. Lee
# ['DeepVision', 'RoboMind']
# ['CloudScale']
# ['AutoNav']
# {'funding': 150000, 'researchers': ['Priya', 'Dev'], 'status': 'ongoing'}
# completed
# 350000
# {'location': 'Dubai', 'ranking': 3, 'faculties': {}}
# {'Corporate Finance': {'credits': 3, 'students_enrolled': 80}, 'Investment Banking': {'credits': 3, 'students_enrolled': 60}}
# AutoNav 400000
# 1330000
# GTU_Singapore
# DeepVision
# RoboMind
# 8
# AI Lab 580000
# {'ongoing': ['NeuralEdge', 'CloudScale', 'AutoNav'], 'completed': ['DeepVision', 'RoboMind']}
# Data Structures
# University: GTU_Singapore
# Project: AutoNav
# {'funding': 400000, 'researchers': ['Jason', 'Lily'], 'status': 'ongoing'}
# University: GTU_Singapore
# Project: AutoNav
# {'funding': 400000, 'researchers': ['Jason', 'Lily'], 'status': 'ongoing'}
